# %%
# IMPORTING IMPORTANT LIBRARIES
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

# %%
# FILE PATH
file_path = '/content/Input.xlsx'
input_data = pd.read_excel(file_path)

# %%
# CREATING A FOLDER TO SAVE SCRAPPED CONTENTS FROM WEBSITES
output_folder = 'scraped_articles'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %%
def scrape_article(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'lxml')

            # EXTRACTING TITLE AND BODIES
            title = soup.find('h1').get_text() if soup.find('h1') else 'No Title'
            article_body = soup.find('div', class_='td-post-content').get_text() if soup.find('div', class_='td-post-content') else 'No Article Text'

            return title, article_body
        else:
            print(f"Failed to fetch URL: {url}, Status Code: {response.status_code}")
            return None, None
    except Exception as e:
        print(f"Error occurred while fetching URL: {url}. Error: {str(e)}")
        return None, None

# %%
for index, row in input_data.iterrows():
    url_id = row['URL_ID']
    url = row['URL']

    # SCRAPPING THE ARTICLE CONTENTS
    title, content = scrape_article(url)

    if title and content:
        # SAVING THE CONTENT AS TXT WITH FILE NAME AS URL_ID
        file_name = f"{url_id}.txt"
        file_path = os.path.join(output_folder, file_name)

        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(f"Title: {title}\n\n{content}")

        print(f"Saved article: {file_name}")

print("Scraping complete!")
# Out:
# Saved article: bctech2011.txt
# Saved article: bctech2012.txt
# Saved article: bctech2013.txt
# Saved article: bctech2014.txt
# Saved article: bctech2015.txt
# Saved article: bctech2016.txt
# Saved article: bctech2017.txt
# Saved article: bctech2018.txt
# Saved article: bctech2019.txt
# Saved article: bctech2020.txt
# Saved article: bctech2021.txt
# Saved article: bctech2022.txt
# Saved article: bctech2023.txt
# Saved article: bctech2024.txt
# Saved article: bctech2025.txt
# Saved article: bctech2026.txt
# Saved article: bctech2027.txt
# Saved article: bctech2028.txt
# Saved article: bctech2029.txt
# Saved article: bctech2030.txt
# Saved article: bctech2031.txt
# Saved article: bctech2032.txt
# Saved article: bctech2033.txt
# Saved article: bctech2034.txt
# Saved article: bctech2035.txt
# Saved article: bctech2036.txt
# Saved article: bctech2037.txt
# Saved article: bctech2038.txt
# Saved article: bctech2039.txt
# Saved article: bctech2040.txt
# Saved article: bctech2041.txt
# Saved article: bctech2042.txt
# Saved article: bctech2043.txt
# Saved article: bctech2044.txt
# Saved article: bctech2045.txt
# Saved article: bctech2046.txt
# Saved article: bctech2047.txt
# Saved article: bctech2048.txt
# Saved article: bctech2049.txt
# Saved article: bctech2050.txt
# Saved article: bctech2051.txt
# Saved article: bctech2052.txt
# Saved article: bctech2053.txt
# Saved article: bctech2054.txt
# Saved article: bctech2055.txt
# Saved article: bctech2056.txt
# Saved article: bctech2057.txt
# Saved article: bctech2058.txt
# Saved article: bctech2059.txt
# Saved article: bctech2060.txt
# Saved article: bctech2061.txt
# Saved article: bctech2062.txt
# Saved article: bctech2063.txt
# Saved article: bctech2064.txt
# Saved article: bctech2065.txt
# Saved article: bctech2066.txt
# Saved article: bctech2067.txt
# Saved article: bctech2068.txt
# Saved article: bctech2069.txt
# Saved article: bctech2070.txt
# Saved article: bctech2071.txt
# Saved article: bctech2072.txt
# Saved article: bctech2073.txt
# Saved article: bctech2074.txt
# Saved article: bctech2075.txt
# Saved article: bctech2076.txt
# Saved article: bctech2077.txt
# Saved article: bctech2078.txt
# Saved article: bctech2079.txt
# Saved article: bctech2080.txt
# Saved article: bctech2081.txt
# Saved article: bctech2082.txt
# Saved article: bctech2083.txt
# Saved article: bctech2084.txt
# Saved article: bctech2085.txt
# Saved article: bctech2086.txt
# Saved article: bctech2087.txt
# Saved article: bctech2088.txt
# Saved article: bctech2089.txt
# Saved article: bctech2090.txt
# Saved article: bctech2091.txt
# Saved article: bctech2092.txt
# Saved article: bctech2093.txt
# Saved article: bctech2094.txt
# Saved article: bctech2095.txt
# Saved article: bctech2096.txt
# Saved article: bctech2097.txt
# Saved article: bctech2098.txt
# Saved article: bctech2099.txt
# Saved article: bctech2100.txt
# Saved article: bctech2101.txt
# Saved article: bctech2102.txt
# Saved article: bctech2103.txt
# Saved article: bctech2104.txt
# Saved article: bctech2105.txt
# Saved article: bctech2106.txt
# Saved article: bctech2107.txt
# Saved article: bctech2108.txt
# Saved article: bctech2109.txt
# Saved article: bctech2110.txt
# Saved article: bctech2111.txt
# Saved article: bctech2112.txt
# Saved article: bctech2113.txt
# Saved article: bctech2114.txt
# Saved article: bctech2115.txt
# Saved article: bctech2116.txt
# Saved article: bctech2117.txt
# Saved article: bctech2118.txt
# Saved article: bctech2119.txt
# Saved article: bctech2120.txt
# Saved article: bctech2121.txt
# Saved article: bctech2122.txt
# Saved article: bctech2123.txt
# Saved article: bctech2124.txt
# Saved article: bctech2125.txt
# Saved article: bctech2126.txt
# Saved article: bctech2127.txt
# Saved article: bctech2128.txt
# Saved article: bctech2129.txt
# Saved article: bctech2130.txt
# Saved article: bctech2131.txt
# Saved article: bctech2132.txt
# Saved article: bctech2133.txt
# Saved article: bctech2134.txt
# Saved article: bctech2135.txt
# Saved article: bctech2136.txt
# Saved article: bctech2137.txt
# Saved article: bctech2138.txt
# Saved article: bctech2139.txt
# Saved article: bctech2140.txt
# Saved article: bctech2141.txt
# Saved article: bctech2142.txt
# Saved article: bctech2143.txt
# Saved article: bctech2144.txt
# Saved article: bctech2145.txt
# Saved article: bctech2146.txt
# Saved article: bctech2147.txt
# Saved article: bctech2148.txt
# Saved article: bctech2149.txt
# Saved article: bctech2150.txt
# Saved article: bctech2151.txt
# Saved article: bctech2152.txt
# Saved article: bctech2153.txt
# Saved article: bctech2154.txt
# Saved article: bctech2155.txt
# Saved article: bctech2156.txt
# Saved article: bctech2157.txt
# Scraping complete!

# %%
################################SCRAPPING DONE NOW FINDING THE VALUES OF POSITIVE NEGATIVE AND ALL THE FACTORES################################
# !pip install textstat
# !pip install nltk
# Out:
# Collecting textstat
#   Downloading textstat-0.7.4-py3-none-any.whl.metadata (14 kB)
# Collecting pyphen (from textstat)
#   Downloading pyphen-0.16.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from textstat) (75.1.0)
# Downloading textstat-0.7.4-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 kB 3.0 MB/s eta 0:00:00
# Downloading pyphen-0.16.0-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 29.5 MB/s eta 0:00:00
# Installing collected packages: pyphen, textstat
# Successfully installed pyphen-0.16.0 textstat-0.7.4
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)

# %%
#importing and downloading directories for text analyzation of articles. we will do it by importing the natural language toolkit directories
#This library is knows as VADER it is specially designed for analyzing sentiments VADER IS KNOWN AS VALENCE AWARE DICTIONARY AND sENTIMENT REASONER

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Download the VADER lexicon (required for the first time)
nltk.download('vader_lexicon')

# Initialize the VADER sentiment analyzer
sia = SentimentIntensityAnalyzer()
scraped_articles_folder = 'scraped_articles'



# Function to analyze sentiment using VADER
def analyze_sentiment_vader(text):
  sentiment = sia.polarity_scores(text)
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
import os
from nltk.sentiment import SentimentIntensityAnalyzer
import pandas as pd
import nltk
nltk.download('vader_lexicon')

# Initialize VADER sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Function to calculate Positive, Negative, and Polarity Scores using VADER
def calculate_sentiment_scores(text):
    sentiment = sia.polarity_scores(text)
    positive_score = sentiment['pos']
    negative_score = sentiment['neg']
    polarity_score = (positive_score - negative_score) / ((positive_score + negative_score) + 0.000001)
    return positive_score, negative_score, polarity_score

# Folder containing the scraped articles
scraped_articles_folder = 'scraped_articles'

# Create an empty list to store data for each article
data = []

# Loop through each article in the folder
for file_name in os.listdir(scraped_articles_folder):
    if file_name.endswith('.txt'):
        file_path = os.path.join(scraped_articles_folder, file_name)

        # Read the article content
        try:
            with open(file_path, 'r', encoding='utf-8') as file:
                text = file.read()
        except Exception as e:
            print(f"Error reading file {file_name}: {str(e)}")
            continue  # Skip this file if there is a reading issue

        # Calculate sentiment scores
        positive_score, negative_score, polarity_score = calculate_sentiment_scores(text)

        # Append the results to the data list
        data.append({
            'File Name': file_name,
            'Positive Score': positive_score,
            'Negative Score': negative_score,
            'Polarity Score': polarity_score
        })

# Convert the data list to a pandas DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to an Excel file
output_excel_file = 'sentiment_analysis_results.xlsx'
df.to_excel(output_excel_file, index=False)

print(f"Sentiment analysis results saved to {output_excel_file}")
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Sentiment analysis results saved to sentiment_analysis_results.xlsx

# %%
import os
import re
from textblob import TextBlob
import textstat
import nltk
nltk.download('punkt')

# Define a function to calculate syllables per word using textstat
def syllable_count(word):
    return textstat.syllable_count(word)

# Define a function to check if a word is complex (3 or more syllables)
def is_complex_word(word):
    return syllable_count(word) >= 3

# Define a function to calculate personal pronouns
def count_personal_pronouns(text):
    pronouns = ['I', 'we', 'my', 'ours', 'us', 'he', 'she', 'him', 'her', 'they', 'them', 'you']
    words = text.lower().split()
    return sum(1 for word in words if word in pronouns)

# Define the main function to calculate all factors
def analyze_text_metrics(text):
    # Initialize TextBlob for sentiment and subjectivity
    blob = TextBlob(text)

    # Sentence Tokenization
    sentences = nltk.sent_tokenize(text)
    num_sentences = len(sentences)

    # Word Tokenization
    words = nltk.word_tokenize(text)
    num_words = len(words)

    # Word count and average word length
    total_word_length = sum(len(word) for word in words)
    avg_word_length = total_word_length / num_words if num_words > 0 else 0

    # Subjectivity Score
    subjectivity_score = blob.sentiment.subjectivity

    # Avg Sentence Length (Number of words per sentence)
    avg_sentence_length = num_words / num_sentences if num_sentences > 0 else 0

    # Complex word count
    complex_words = [word for word in words if is_complex_word(word)]
    num_complex_words = len(complex_words)

    # Percentage of complex words
    percentage_complex_words = (num_complex_words / num_words) * 100 if num_words > 0 else 0

    # FOG Index = 0.4 * (average sentence length + percentage of complex words)
    fog_index = 0.4 * (avg_sentence_length + percentage_complex_words)

    # Avg Number of Words per Sentence
    avg_words_per_sentence = num_words / num_sentences if num_sentences > 0 else 0

    # Syllables per word
    syllables = sum(syllable_count(word) for word in words)
    avg_syllables_per_word = syllables / num_words if num_words > 0 else 0

    # Count personal pronouns
    personal_pronouns_count = count_personal_pronouns(text)

    return {
        'subjectivity_score': subjectivity_score,
        'avg_sentence_length': avg_sentence_length,
        'percentage_complex_words': percentage_complex_words,
        'fog_index': fog_index,
        'avg_words_per_sentence': avg_words_per_sentence,
        'complex_word_count': num_complex_words,
        'word_count': num_words,
        'avg_syllables_per_word': avg_syllables_per_word,
        'personal_pronouns': personal_pronouns_count,
        'avg_word_length': avg_word_length
    }

# Folder containing the scraped articles
scraped_articles_folder = 'scraped_articles'

# Loop through each article and calculate metrics
for file_name in os.listdir(scraped_articles_folder):
    if file_name.endswith('.txt'):
        file_path = os.path.join(scraped_articles_folder, file_name)

        # Read the article content
        with open(file_path, 'r', encoding='utf-8') as file:
            text = file.read()

        # Analyze text metrics
        metrics = analyze_text_metrics(text)

        # Print the result for each article
        print(f"File: {file_name}")
        print(f"Subjectivity Score: {metrics['subjectivity_score']}")
        print(f"Avg Sentence Length: {metrics['avg_sentence_length']}")
        print(f"Percentage of Complex Words: {metrics['percentage_complex_words']}")
        print(f"FOG Index: {metrics['fog_index']}")
        print(f"Avg Words per Sentence: {metrics['avg_words_per_sentence']}")
        print(f"Complex Word Count: {metrics['complex_word_count']}")
        print(f"Word Count: {metrics['word_count']}")
        print(f"Avg Syllables per Word: {metrics['avg_syllables_per_word']}")
        print(f"Personal Pronouns: {metrics['personal_pronouns']}")
        print(f"Avg Word Length: {metrics['avg_word_length']}")
        print("\n" + "-"*40 + "\n")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# File: bctech2058.txt
# Subjectivity Score: 0.28650568181818176
# Avg Sentence Length: 123.4
# Percentage of Complex Words: 20.42139384116694
# FOG Index: 57.528557536466785
# Avg Words per Sentence: 123.4
# Complex Word Count: 126
# Word Count: 617
# Avg Syllables per Word: 1.7747163695299837
# Personal Pronouns: 4
# Avg Word Length: 6.165316045380875
#
# ----------------------------------------
#
# File: bctech2130.txt
# Subjectivity Score: 0.4
# Avg Sentence Length: 113.0
# Percentage of Complex Words: 29.20353982300885
# FOG Index: 56.88141592920354
# Avg Words per Sentence: 113.0
# Complex Word Count: 33
# Word Count: 113
# Avg Syllables per Word: 1.9734513274336283
# Personal Pronouns: 0
# Avg Word Length: 7.371681415929204
#
# ----------------------------------------
#
# File: bctech2076.txt
# Subjectivity Score: 0.4807017543859649
# Avg Sentence Length: 56.75
# Percentage of Complex Words: 18.28193832599119
# FOG Index: 30.01277533039648
# Avg Words per Sentence: 56.75
# Complex Word Count: 83
# Word Count: 454
# Avg Syllables per Word: 1.5947136563876652
# Personal Pronouns: 12
# Avg Word Length: 5.627753303964758
#
# ----------------------------------------
#
# File: bctech2030.txt
# Subjectivity Score: 0.44390243902439025
# Avg Sentence Length: 41.0
# Percentage of Complex Words: 19.024390243902438
# Complex Word Count: 77
# Word Count: 478
# Avg Syllables per Word: 1.5711297071129706
# Personal Pronouns: 1
# Avg Word Length: 5.163179916317992
#
# ----------------------------------------
#
# File: bctech2072.txt
# Subjectivity Score: 0.3159090909090908
# Avg Sentence Length: 42.2
# Percentage of Complex Words: 20.379146919431278
# FOG Index: 25.031658767772512
# Avg Words per Sentence: 42.2
# Complex Word Count: 43
# Word Count: 211
# Avg Syllables per Word: 1.6777251184834123
# Personal Pronouns: 3
# Avg Word Length: 5.924170616113744
#
# ----------------------------------------
#
# File: bctech2011.txt
# Subjectivity Score: 0.3937866730970184
# Avg Sentence Length: 25.2
# Percentage of Complex Words: 30.400276052449964
# FOG Index: 22.24011042097999
# Avg Words per Sentence: 25.2
# Complex Word Count: 881
# Word Count: 2898
# Avg Syllables per Word: 1.8505866114561766
# Personal Pronouns: 4
# Avg Word Length: 5.888543823326432
#
# ----------------------------------------
#
# File: bctech2026.txt
# Subjectivity Score: 0.5211566725455613
# Avg Sentence Length: 39.86363636363637
# Percentage of Complex Words: 19.726339794754846
# FOG Index: 23.835990463356485
# Avg Words per Sentence: 39.86363636363637
# Complex Word Count: 173
# Word Count: 877
# Avg Syllables per Word: 1.6248574686431014
# Personal Pronouns: 11
# Avg Word Length: 5.4971493728620295
#
# ----------------------------------------
#
# File: bctech2143.txt
# Subjectivity Score: 0.14960317460317463
# Avg Sentence Length: 115.0
# Percentage of Complex Words: 22.608695652173914
# FOG Index: 55.04347826086956
# Avg Words per Sentence: 115.0
# Complex Word Count: 52
# Word Count: 230
# Avg Syllables per Word: 1.7
# Personal Pronouns: 0
# Avg Word Length: 6.030434782608696
#
# ----------------------------------------
#
# File: bctech2140.txt
# Subjectivity Score: 0.43303030303030293
# Avg Sentence Length: 95.8
# Percentage of Complex Words: 15.657620041753653
# FOG Index: 44.58304801670146
# Avg Words per Sentence: 95.8
# Complex Word Count: 75
# Word Count: 479
# Avg Syllables per Word: 1.5511482254697286
# Personal Pronouns: 5
# Avg Word Length: 5.068893528183716
#
# ----------------------------------------
#
# File: bctech2051.txt
# Subjectivity Score: 0.4451388888888889
# Avg Sentence Length: 56.083333333333336
# Percentage of Complex Words: 15.75037147102526
# FOG Index: 28.733481921743437
# Avg Words per Sentence: 56.083333333333336
# Complex Word Count: 106
# Word Count: 673
# Avg Syllables per Word: 1.5973254086181279
# Personal Pronouns: 11
# Avg Word Length: 5.445765230312036
#
# ----------------------------------------
#
# File: bctech2114.txt
# Subjectivity Score: 0.22380952380952382
# Avg Sentence Length: 48.2
# Percentage of Complex Words: 17.42738589211618
# FOG Index: 26.250954356846474
# Avg Words per Sentence: 48.2
# Complex Word Count: 42
# Word Count: 241
# Avg Syllables per Word: 1.6431535269709543
# Personal Pronouns: 0
# Avg Word Length: 5.526970954356846
#
# ----------------------------------------
#
# File: bctech2106.txt
# Subjectivity Score: 0.29949874686716793
# Avg Sentence Length: 58.75
# Percentage of Complex Words: 19.148936170212767
# FOG Index: 31.159574468085108
# Avg Words per Sentence: 58.75
# Complex Word Count: 45
# Word Count: 235
#
# ----------------------------------------
#
# File: bctech2042.txt
# Subjectivity Score: 0.25416666666666665
# Avg Sentence Length: 87.33333333333333
# Percentage of Complex Words: 14.50381679389313
# FOG Index: 40.73486005089059
# Avg Words per Sentence: 87.33333333333333
# Complex Word Count: 38
# Word Count: 262
# Avg Syllables per Word: 1.5305343511450382
# Personal Pronouns: 5
# Avg Word Length: 5.374045801526718
#
# ----------------------------------------
#
# File: bctech2088.txt
# Subjectivity Score: 0.504424603174603
# Avg Sentence Length: 48.5
# Percentage of Complex Words: 20.962199312714777
# FOG Index: 27.78487972508591
# Avg Words per Sentence: 48.5
# Complex Word Count: 61
# Word Count: 291
# Avg Syllables per Word: 1.7731958762886597
# Personal Pronouns: 8
# Avg Word Length: 5.804123711340206
#
# ----------------------------------------
#
# File: bctech2119.txt
# Subjectivity Score: 0.4708333333333332
# Avg Sentence Length: 33.7
# Percentage of Complex Words: 13.353115727002967
# FOG Index: 18.821246290801188
# Avg Words per Sentence: 33.7
# Complex Word Count: 45
# Word Count: 337
# Avg Syllables per Word: 1.5014836795252227
# Personal Pronouns: 4
# Avg Word Length: 5.083086053412463
#
# ----------------------------------------
#
# File: bctech2052.txt
# Subjectivity Score: 0.3518037518037518
# Avg Sentence Length: 27.0
# Percentage of Complex Words: 14.074074074074074
# FOG Index: 16.42962962962963
# Avg Words per Sentence: 27.0
# Complex Word Count: 57
# Word Count: 405
# Avg Syllables per Word: 1.4197530864197532
# Personal Pronouns: 14
# Avg Word Length: 4.891358024691358
#
# ----------------------------------------
#
# File: bctech2018.txt
# Subjectivity Score: 0.27022727272727265
# Avg Sentence Length: 21.63157894736842
# Percentage of Complex Words: 23.600973236009732
# FOG Index: 18.09302087335126
# Avg Words per Sentence: 21.63157894736842
# Complex Word Count: 97
# Word Count: 411
# Avg Syllables per Word: 1.7639902676399026
# Personal Pronouns: 1
# Avg Word Length: 5.975669099756691
#
# ----------------------------------------
#
# File: bctech2040.txt
# Subjectivity Score: 0.22857142857142862
# Avg Sentence Length: 185.0
# Percentage of Complex Words: 16.216216216216218
# FOG Index: 80.4864864864865
# Avg Words per Sentence: 185.0
# Complex Word Count: 60
# Word Count: 370
# Avg Syllables per Word: 1.5810810810810811
# Personal Pronouns: 14
# Avg Word Length: 5.527027027027027
#
# ----------------------------------------
#
# File: bctech2113.txt
# Subjectivity Score: 0.4318181818181818
# Avg Sentence Length: 67.85714285714286
# Percentage of Complex Words: 19.57894736842105
# FOG Index: 34.974436090225566
# Avg Words per Sentence: 67.85714285714286
# Complex Word Count: 93
# Word Count: 475
# Avg Syllables per Word: 1.6673684210526316
# Personal Pronouns: 8
# Avg Word Length: 5.336842105263158
#
# ----------------------------------------
#
# File: bctech2107.txt
# Subjectivity Score: 0.3672068511198946
# Avg Sentence Length: 73.8
# Percentage of Complex Words: 14.905149051490515
# FOG Index: 35.4820596205962
# Avg Words per Sentence: 73.8
# Complex Word Count: 55
# Word Count: 369
# Avg Syllables per Word: 1.5582655826558265
# Personal Pronouns: 6
# Avg Word Length: 5.4986449864498645
#
# ----------------------------------------
#
# File: bctech2157.txt
# Subjectivity Score: 0.2976190476190476
# Avg Sentence Length: 40.333333333333336
# Percentage of Complex Words: 21.487603305785125
# FOG Index: 24.728374655647386
# Avg Words per Sentence: 40.333333333333336
# Complex Word Count: 26
# Word Count: 121
# Avg Syllables per Word: 1.7272727272727273
# Personal Pronouns: 1
# Avg Word Length: 5.917355371900826
#
# ----------------------------------------
#
# File: bctech2129.txt
# Subjectivity Score: 0.3
# Avg Sentence Length: 62.0
# Percentage of Complex Words: 29.03225806451613
# FOG Index: 36.41290322580645
# Avg Words per Sentence: 62.0
# Complex Word Count: 18
# Word Count: 62
# Avg Syllables per Word: 2.2580645161290325
# Personal Pronouns: 0
# Avg Word Length: 11.112903225806452
#
# ----------------------------------------
#
# File: bctech2115.txt
# Subjectivity Score: 0.4605952380952381
# Avg Sentence Length: 27.833333333333332
# Percentage of Complex Words: 14.071856287425149
# FOG Index: 16.762075848303393
# Avg Words per Sentence: 27.833333333333332
# Complex Word Count: 141
# Word Count: 1002
# Avg Syllables per Word: 1.4910179640718564
# Personal Pronouns: 14
# Avg Word Length: 5.075848303393213
#
# ----------------------------------------
#
# File: bctech2035.txt
# Subjectivity Score: 0.604754922496858
# Avg Sentence Length: 24.677419354838708
# Percentage of Complex Words: 23.398692810457515
# FOG Index: 19.23044486611849
# Avg Words per Sentence: 24.677419354838708
# Complex Word Count: 179
# Word Count: 765
# Avg Syllables per Word: 1.7333333333333334
# Personal Pronouns: 5
# Avg Word Length: 5.602614379084967
#
# ----------------------------------------
#
# File: bctech2031.txt
# Subjectivity Score: 0.404516317016317
# Avg Sentence Length: 43.708333333333336
# Percentage of Complex Words: 18.779790276453763
# FOG Index: 24.99524944391484
# Avg Words per Sentence: 43.708333333333336
# Complex Word Count: 197
# Word Count: 1049
# Avg Syllables per Word: 1.6263107721639656
# Personal Pronouns: 16
# Avg Word Length: 5.695900857959962
#
# ----------------------------------------
#
# File: bctech2090.txt
# Subjectivity Score: 0.37499999999999994
# Avg Sentence Length: 106.4
# Percentage of Complex Words: 15.601503759398497
# FOG Index: 48.8006015037594
# Avg Words per Sentence: 106.4
# Complex Word Count: 83
# Word Count: 532
# Avg Syllables per Word: 1.5432330827067668
# Personal Pronouns: 1
# Avg Word Length: 5.43984962406015
#
# ----------------------------------------
#
# File: bctech2152.txt
# Subjectivity Score: 0.4741418041418041
# Avg Sentence Length: 60.0
# Percentage of Complex Words: 23.666666666666668
# FOG Index: 33.46666666666667
# Avg Words per Sentence: 60.0
# Complex Word Count: 142
# Word Count: 600
# Avg Syllables per Word: 1.7383333333333333
# Personal Pronouns: 2
# Avg Word Length: 5.673333333333333
#
# ----------------------------------------
#
# File: bctech2069.txt
# Subjectivity Score: 0.3414285714285714
# Avg Sentence Length: 72.33333333333333
# Percentage of Complex Words: 18.89400921658986
# FOG Index: 36.49093701996928
# Avg Words per Sentence: 72.33333333333333
# Complex Word Count: 41
# Word Count: 217
# Avg Syllables per Word: 1.695852534562212
# Personal Pronouns: 3
# Avg Word Length: 6.129032258064516
#
# ----------------------------------------
#
# File: bctech2142.txt
# File: bctech2066.txt
# Subjectivity Score: 0.41704545454545455
# Avg Sentence Length: 42.333333333333336
# Percentage of Complex Words: 18.11023622047244
# FOG Index: 24.17742782152231
# Avg Words per Sentence: 42.333333333333336
# Complex Word Count: 46
# Word Count: 254
# Avg Syllables per Word: 1.5748031496062993
# Personal Pronouns: 2
# Avg Word Length: 5.496062992125984
#
# ----------------------------------------
#
# File: bctech2046.txt
# Subjectivity Score: 0.15
# Avg Sentence Length: 32.125
# Percentage of Complex Words: 15.953307392996107
# FOG Index: 19.231322957198444
# Avg Words per Sentence: 32.125
# Complex Word Count: 41
# Word Count: 257
# Avg Syllables per Word: 1.6264591439688716
# Personal Pronouns: 6
# Avg Word Length: 5.801556420233463
#
# ----------------------------------------
#
# File: bctech2154.txt
# Subjectivity Score: 0.25350349320646354
# Avg Sentence Length: 46.483870967741936
# Percentage of Complex Words: 15.336571825121442
# FOG Index: 24.72817711714535
# Avg Words per Sentence: 46.483870967741936
# Complex Word Count: 221
# Word Count: 1441
# Avg Syllables per Word: 1.583622484385843
# Personal Pronouns: 5
# Avg Word Length: 5.215822345593338
#
# ----------------------------------------
#
# File: bctech2036.txt
# Subjectivity Score: 0.3813629703629704
# Avg Sentence Length: 22.15909090909091
# Percentage of Complex Words: 17.846153846153847
# FOG Index: 16.002097902097905
# Avg Words per Sentence: 22.15909090909091
# Complex Word Count: 174
# Word Count: 975
# Avg Syllables per Word: 1.5323076923076924
# Personal Pronouns: 9
# Avg Word Length: 5.09948717948718
#
# ----------------------------------------
#
# File: bctech2134.txt
# Subjectivity Score: 0.4
# Avg Sentence Length: 43.5
# Percentage of Complex Words: 27.586206896551722
# FOG Index: 28.43448275862069
# Avg Words per Sentence: 43.5
# Complex Word Count: 24
# Word Count: 87
# Avg Syllables per Word: 1.9080459770114941
# Personal Pronouns: 0
# Avg Word Length: 7.551724137931035
#
# ----------------------------------------
#
# File: bctech2021.txt
# Subjectivity Score: 0.42400266400266395
# Avg Sentence Length: 11.702127659574469
# Percentage of Complex Words: 25.454545454545453
# FOG Index: 14.862669245647972
# Avg Words per Sentence: 11.702127659574469
# Complex Word Count: 140
# Word Count: 550
# Avg Syllables per Word: 1.7945454545454544
# Personal Pronouns: 1
# Avg Word Length: 6.136363636363637
#
# ----------------------------------------
#
# File: bctech2028.txt
# Subjectivity Score: 0.4739003280669948
# Avg Sentence Length: 35.107142857142854
# Percentage of Complex Words: 17.293997965412004
# FOG Index: 20.960456329021945
# Avg Words per Sentence: 35.107142857142854
# Complex Word Count: 170
# Word Count: 983
# Avg Syllables per Word: 1.607324516785351
# Personal Pronouns: 3
# Avg Word Length: 5.477110885045779
#
# ----------------------------------------
#
# File: bctech2087.txt
# Subjectivity Score: 0.45476190476190476
# Avg Sentence Length: 59.5
# Percentage of Complex Words: 15.966386554621847
# FOG Index: 30.186554621848742
# Avg Words per Sentence: 59.5
# Complex Word Count: 57
# Word Count: 357
# Avg Syllables per Word: 1.5322128851540617
# Personal Pronouns: 6
# Avg Word Length: 5.310924369747899
#
# ----------------------------------------
#
# File: bctech2117.txt
# Subjectivity Score: 0.42333333333333334
# Avg Sentence Length: 36.888888888888886
# Percentage of Complex Words: 16.867469879518072
# FOG Index: 21.502543507362784
# Avg Words per Sentence: 36.888888888888886
# Complex Word Count: 56
# Word Count: 332
# Avg Syllables per Word: 1.4879518072289157
# Personal Pronouns: 1
# Avg Word Length: 5.117469879518072
#
# ----------------------------------------
#
# File: bctech2098.txt
# Subjectivity Score: 0.3829437229437228
# Avg Sentence Length: 29.533333333333335
# Percentage of Complex Words: 14.672686230248308
# FOG Index: 17.68240782543266
# Avg Words per Sentence: 29.533333333333335
# Complex Word Count: 65
# Word Count: 443
# Avg Syllables per Word: 1.528216704288939
# Personal Pronouns: 4
# Avg Word Length: 5.672686230248307
#
# ----------------------------------------
#
# File: bctech2151.txt
# Subjectivity Score: 0.40022535260438485
# Avg Sentence Length: 49.26315789473684
# Percentage of Complex Words: 14.743589743589745
# FOG Index: 25.602699055330636
# Avg Words per Sentence: 49.26315789473684
# Complex Word Count: 138
# Word Count: 936
# Avg Syllables per Word: 1.5876068376068375
# Personal Pronouns: 2
# Avg Word Length: 5.428418803418803
#
# ----------------------------------------
#
# File: bctech2127.txt
# Subjectivity Score: 0.35163170163170154
# Avg Sentence Length: 40.48571428571429
# Percentage of Complex Words: 12.491178546224418
# FOG Index: 21.190757132775484
# Avg Words per Sentence: 40.48571428571429
# Complex Word Count: 177
# Word Count: 1417
# Avg Syllables per Word: 1.465772759350741
# Personal Pronouns: 12
# Avg Word Length: 5.235709244883557
#
# ----------------------------------------
#
# File: bctech2077.txt
# Subjectivity Score: 0.5463406385281385
# Avg Sentence Length: 39.666666666666664
# Percentage of Complex Words: 11.974789915966387
# FOG Index: 20.656582633053223
# Avg Words per Sentence: 39.666666666666664
# Complex Word Count: 57
# Word Count: 476
# Avg Syllables per Word: 1.5126050420168067
# Personal Pronouns: 17
# Avg Word Length: 5.224789915966387
#
# ----------------------------------------
#
# File: bctech2024.txt
# Subjectivity Score: 0.4874561403508771
# Avg Sentence Length: 35.91304347826087
# Percentage of Complex Words: 21.791767554479417
# FOG Index: 23.081924413096115
# Avg Words per Sentence: 35.91304347826087
# Complex Word Count: 180
# Word Count: 826
# Avg Syllables per Word: 1.6973365617433414
# Personal Pronouns: 13
# Avg Word Length: 5.606537530266344
#
# ----------------------------------------
#
# File: bctech2050.txt
# Subjectivity Score: 0.2621031746031745
# Avg Sentence Length: 72.8
# Percentage of Complex Words: 15.10989010989011
# FOG Index: 35.16395604395605
# Avg Words per Sentence: 72.8
# Complex Word Count: 55
# Word Count: 364
# Avg Syllables per Word: 1.5934065934065933
# Personal Pronouns: 3
# Avg Word Length: 5.532967032967033
#
# ----------------------------------------
#
# File: bctech2014.txt
# Subjectivity Score: 0.3135515999152363
# Avg Sentence Length: 10.893617021276595
# Percentage of Complex Words: 25.0
# FOG Index: 14.35744680851064
# Avg Words per Sentence: 10.893617021276595
# Complex Word Count: 128
# Word Count: 512
# Avg Syllables per Word: 1.818359375
# Personal Pronouns: 1
# Avg Word Length: 6.265625
#
# ----------------------------------------
#
# File: bctech2100.txt
# Avg Sentence Length: 39.689655172413794
# Percentage of Complex Words: 17.636837532580365
# FOG Index: 22.930597081997664
# Avg Words per Sentence: 39.689655172413794
# Complex Word Count: 203
# Word Count: 1151
# Avg Syllables per Word: 1.524761077324066
# Personal Pronouns: 10
# Avg Word Length: 5.056472632493484
#
# ----------------------------------------
#
# File: bctech2125.txt
# Subjectivity Score: 0.4512866762866762
# Avg Sentence Length: 83.25
# Percentage of Complex Words: 26.126126126126124
# FOG Index: 43.75045045045045
# Avg Words per Sentence: 83.25
# Complex Word Count: 87
# Word Count: 333
# Avg Syllables per Word: 1.834834834834835
# Personal Pronouns: 0
# Avg Word Length: 6.354354354354355
#
# ----------------------------------------
#
# File: bctech2071.txt
# Subjectivity Score: 0.2
# Avg Sentence Length: 46.25
# Percentage of Complex Words: 21.08108108108108
# FOG Index: 26.932432432432435
# Avg Words per Sentence: 46.25
# Complex Word Count: 39
# Word Count: 185
# Avg Syllables per Word: 1.7027027027027026
# Personal Pronouns: 2
# Avg Word Length: 6.0864864864864865
#
# ----------------------------------------
#
# File: bctech2017.txt
# Subjectivity Score: 0.3071969696969696
# Avg Sentence Length: 16.08695652173913
# Percentage of Complex Words: 25.945945945945947
# FOG Index: 16.81316098707403
# Avg Words per Sentence: 16.08695652173913
# Complex Word Count: 96
# Word Count: 370
# Avg Syllables per Word: 1.7864864864864864
# Personal Pronouns: 1
# Avg Word Length: 6.216216216216216
#
# ----------------------------------------
#
# File: bctech2060.txt
# Subjectivity Score: 0.40714285714285714
# Avg Sentence Length: 83.0
# Percentage of Complex Words: 18.97590361445783
# FOG Index: 40.790361445783134
# Avg Words per Sentence: 83.0
# Complex Word Count: 63
# Word Count: 332
# Avg Syllables per Word: 1.6475903614457832
# Personal Pronouns: 2
# Avg Word Length: 5.554216867469879
#
# ----------------------------------------
#
# File: bctech2073.txt
# Subjectivity Score: 0.2625
# Avg Sentence Length: 69.0
# Percentage of Complex Words: 23.18840579710145
# FOG Index: 36.87536231884058
# Avg Words per Sentence: 69.0
# Complex Word Count: 32
# Word Count: 138
# Avg Syllables per Word: 1.7463768115942029
# Personal Pronouns: 2
# Avg Word Length: 6.72463768115942
#
# ----------------------------------------
#
# File: bctech2156.txt
# Subjectivity Score: 0.4714285714285714
# Avg Sentence Length: 148.0
# Percentage of Complex Words: 16.89189189189189
# FOG Index: 65.95675675675676
# Avg Words per Sentence: 148.0
# Complex Word Count: 25
# Word Count: 148
# Avg Syllables per Word: 1.5810810810810811
# Personal Pronouns: 0
# Avg Word Length: 5.1891891891891895
#
# ----------------------------------------
#
# File: bctech2057.txt
# Subjectivity Score: 0.3806334050564819
# Avg Sentence Length: 50.666666666666664
# Percentage of Complex Words: 16.447368421052634
# FOG Index: 26.84561403508772
# Avg Words per Sentence: 50.666666666666664
# Complex Word Count: 75
# Word Count: 456
# Avg Syllables per Word: 1.5789473684210527
# Personal Pronouns: 2
# Avg Word Length: 5.642543859649122
#
# ----------------------------------------
#
# File: bctech2155.txt
# Subjectivity Score: 0.35295698924731184
# Avg Sentence Length: 52.0
# Percentage of Complex Words: 12.5
# FOG Index: 25.8
# Avg Words per Sentence: 52.0
# Complex Word Count: 52
# Word Count: 416
# Avg Syllables per Word: 1.5168269230769231
# Personal Pronouns: 10
# Avg Word Length: 5.0889423076923075
#
# ----------------------------------------
#
# File: bctech2045.txt
# Subjectivity Score: 0.4474489795918367
# Avg Sentence Length: 29.928571428571427
# Percentage of Complex Words: 19.331742243436754
# FOG Index: 19.704125468803273
# Avg Words per Sentence: 29.928571428571427
# Complex Word Count: 81
# Word Count: 419
# Avg Syllables per Word: 1.5489260143198091
# Personal Pronouns: 9
# Avg Word Length: 5.37708830548926
#
# ----------------------------------------
#
# File: bctech2109.txt
# Subjectivity Score: 0.38033910533910537
# Avg Sentence Length: 90.0
# Percentage of Complex Words: 20.74074074074074
# FOG Index: 44.2962962962963
# Avg Words per Sentence: 90.0
# Complex Word Count: 112
# Word Count: 540
# Avg Syllables per Word: 1.614814814814815
# Personal Pronouns: 5
# Avg Word Length: 5.42037037037037
#
# ----------------------------------------
#
# File: bctech2081.txt
# Subjectivity Score: 0.3631313131313131
# Avg Sentence Length: 35.64
# Percentage of Complex Words: 21.099887766554435
# FOG Index: 22.695955106621774
# Avg Words per Sentence: 35.64
# Complex Word Count: 188
# Word Count: 891
# Avg Syllables per Word: 1.6655443322109988
# Personal Pronouns: 5
# Avg Word Length: 5.616161616161616
#
# ----------------------------------------
#
# File: bctech2049.txt
# Subjectivity Score: 0.37676767676767675
# Avg Sentence Length: 51.6
# Percentage of Complex Words: 13.953488372093023
# FOG Index: 26.221395348837213
# Avg Words per Sentence: 51.6
# Complex Word Count: 72
# Word Count: 516
# Avg Syllables per Word: 1.5155038759689923
# Personal Pronouns: 10
# Avg Word Length: 5.187984496124031
#
# ----------------------------------------
#
# File: bctech2044.txt
# Subjectivity Score: 0.21837822671156001
# Avg Sentence Length: 30.72222222222222
# Percentage of Complex Words: 18.44484629294756
# FOG Index: 19.666827406067913
# Avg Words per Sentence: 30.72222222222222
# Complex Word Count: 102
# Word Count: 553
# Avg Syllables per Word: 1.4990958408679929
# Personal Pronouns: 8
# Avg Word Length: 5.8589511754068715
#
# ----------------------------------------
#
# File: bctech2153.txt
# Subjectivity Score: 0.41299648268398265
# Avg Sentence Length: 77.58333333333333
# Percentage of Complex Words: 17.508055853920514
# FOG Index: 38.036555674901535
# Avg Words per Sentence: 77.58333333333333
# Complex Word Count: 163
# Word Count: 931
# Avg Syllables per Word: 1.6337271750805586
# Personal Pronouns: 3
# Avg Word Length: 5.412459720730397
#
# ----------------------------------------
#
# File: bctech2147.txt
# Subjectivity Score: 0.3244047619047619
# Avg Sentence Length: 34.285714285714285
# Percentage of Complex Words: 19.166666666666668
# FOG Index: 21.38095238095238
# Avg Words per Sentence: 34.285714285714285
# Complex Word Count: 46
# Word Count: 240
# Avg Syllables per Word: 1.6125
# Personal Pronouns: 0
# Avg Word Length: 5.741666666666666
#
# ----------------------------------------
#
# File: bctech2056.txt
# Subjectivity Score: 0.41242506535609974
# Avg Sentence Length: 24.18
# Percentage of Complex Words: 16.708023159636063
# FOG Index: 16.355209263854427
# FOG Index: 21.558798011462585
# Avg Words per Sentence: 37.55172413793103
# Complex Word Count: 178
# Word Count: 1089
# Avg Syllables per Word: 1.537190082644628
# Personal Pronouns: 8
# Avg Word Length: 5.2699724517906334
#
# ----------------------------------------
#
# File: bctech2128.txt
# Subjectivity Score: 0.39397061272061273
# Avg Sentence Length: 42.76470588235294
# Percentage of Complex Words: 19.257221458046768
# FOG Index: 24.80877093615989
# Avg Words per Sentence: 42.76470588235294
# Complex Word Count: 140
# Word Count: 727
# Avg Syllables per Word: 1.702888583218707
# Personal Pronouns: 5
# Avg Word Length: 5.909215955983494
#
# ----------------------------------------
#
# File: bctech2101.txt
# Subjectivity Score: 0.5399999999999999
# Avg Sentence Length: 164.5
# Percentage of Complex Words: 14.893617021276595
# FOG Index: 71.75744680851064
# Avg Words per Sentence: 164.5
# Complex Word Count: 49
# Word Count: 329
# Avg Syllables per Word: 1.5623100303951367
# Personal Pronouns: 1
# Avg Word Length: 5.550151975683891
#
# ----------------------------------------
#
# File: bctech2102.txt
# Subjectivity Score: 0.3982142857142857
# Avg Sentence Length: 41.96296296296296
# Percentage of Complex Words: 17.03442188879082
# FOG Index: 23.598953940701513
# Avg Words per Sentence: 41.96296296296296
# Complex Word Count: 193
# Word Count: 1133
# Avg Syllables per Word: 1.5039717563989408
# Personal Pronouns: 14
# Avg Word Length: 5.043248014121801
#
# ----------------------------------------
#
# File: bctech2015.txt
# Subjectivity Score: 0.3797122417812073
# Avg Sentence Length: 29.59090909090909
# Percentage of Complex Words: 24.11674347158218
# FOG Index: 21.48306102499651
# Avg Words per Sentence: 29.59090909090909
# Complex Word Count: 157
# Word Count: 651
# Avg Syllables per Word: 1.6897081413210446
# Personal Pronouns: 1
# Avg Word Length: 5.554531490015361
#
# ----------------------------------------
#
# File: bctech2094.txt
# Subjectivity Score: 0.3657051282051281
# Avg Sentence Length: 163.0
# Percentage of Complex Words: 14.723926380368098
# FOG Index: 71.08957055214724
# Avg Words per Sentence: 163.0
# Complex Word Count: 48
# Word Count: 326
# Avg Syllables per Word: 1.5429447852760736
# Personal Pronouns: 0
# Avg Word Length: 5.58282208588957
#
# ----------------------------------------
#
# File: bctech2089.txt
# Subjectivity Score: 0.2679144385026738
# Avg Sentence Length: 36.72727272727273
# Percentage of Complex Words: 12.376237623762377
# FOG Index: 19.641404140414043
# Avg Words per Sentence: 36.72727272727273
# Complex Word Count: 50
# Word Count: 404
# Avg Syllables per Word: 1.4455445544554455
# Personal Pronouns: 12
# Avg Word Length: 5.096534653465347
#
# ----------------------------------------
#
# File: bctech2064.txt
# Subjectivity Score: 0.3907894736842104
# Avg Sentence Length: 23.526315789473685
# Percentage of Complex Words: 17.449664429530202
# FOG Index: 16.390392087601555
# Avg Words per Sentence: 23.526315789473685
# Complex Word Count: 78
# Word Count: 447
# Avg Syllables per Word: 1.5436241610738255
# Personal Pronouns: 8
# Avg Word Length: 5.39821029082774
#
# ----------------------------------------
#
# File: bctech2148.txt
# Subjectivity Score: 0.2404761904761905
# Avg Sentence Length: 124.5
# Percentage of Complex Words: 18.87550200803213
# FOG Index: 57.35020080321286
# Avg Words per Sentence: 124.5
# Complex Word Count: 47
# Word Count: 249
# Avg Syllables per Word: 1.6305220883534137
# Personal Pronouns: 0
# Avg Word Length: 5.586345381526105
#
# ----------------------------------------
#
# File: bctech2065.txt
# Subjectivity Score: 0.1933908045977011
# Avg Sentence Length: 42.63636363636363
# Percentage of Complex Words: 17.91044776119403
# FOG Index: 24.218724559023066
# Avg Words per Sentence: 42.63636363636363
# Complex Word Count: 84
# Word Count: 469
# Avg Syllables per Word: 1.4477611940298507
# Personal Pronouns: 4
# Avg Word Length: 4.974413646055437
#
# ----------------------------------------
#
# File: bctech2112.txt
# Subjectivity Score: 0.32586805555555554
# Avg Sentence Length: 126.5
# Percentage of Complex Words: 21.73913043478261
# FOG Index: 59.295652173913055
# Avg Words per Sentence: 126.5
# Complex Word Count: 55
# Word Count: 253
# Avg Syllables per Word: 1.7588932806324111
# Personal Pronouns: 3
# Avg Word Length: 6.031620553359684
#
# ----------------------------------------
#
# File: bctech2118.txt
# Subjectivity Score: 0.4122222222222222
# Avg Sentence Length: 58.25
# Percentage of Complex Words: 19.742489270386265
# FOG Index: 31.19699570815451
# Avg Words per Sentence: 58.25
# Complex Word Count: 46
# Word Count: 233
# Avg Syllables per Word: 1.793991416309013
# Personal Pronouns: 0
# Avg Word Length: 6.15450643776824
#
# ----------------------------------------
#
# File: bctech2141.txt
# Subjectivity Score: 0.42500000000000004
# Avg Sentence Length: 40.666666666666664
# Percentage of Complex Words: 15.846994535519126
# FOG Index: 22.605464480874318
# Avg Words per Sentence: 40.666666666666664
# Complex Word Count: 58
# Word Count: 366
# Avg Syllables per Word: 1.5628415300546448
# Personal Pronouns: 1
# Avg Word Length: 5.491803278688525
#
# ----------------------------------------
#
# File: bctech2025.txt
# Subjectivity Score: 0.4810426656676657
# Avg Sentence Length: 35.791666666666664
# Percentage of Complex Words: 18.859138533178115
# FOG Index: 21.860322079937916
# Avg Words per Sentence: 35.791666666666664
# Complex Word Count: 162
# Word Count: 859
# Avg Syllables per Word: 1.6554132712456344
# Personal Pronouns: 22
# Avg Word Length: 5.448195576251456
#
# ----------------------------------------
#
# File: bctech2084.txt
# Subjectivity Score: 0.4471428571428571
# Avg Sentence Length: 123.5
# Percentage of Complex Words: 12.145748987854251
# FOG Index: 54.25829959514171
# Avg Words per Sentence: 123.5
# Complex Word Count: 30
# Word Count: 247
# Avg Syllables per Word: 1.3279352226720649
# Personal Pronouns: 2
# Avg Word Length: 4.578947368421052
#
# ----------------------------------------
#
# File: bctech2078.txt
# Subjectivity Score: 0.48046874999999994
# Avg Sentence Length: 40.53846153846154
# Percentage of Complex Words: 13.282732447817835
# FOG Index: 21.528477594511752
# Avg Words per Sentence: 40.53846153846154
# Complex Word Count: 70
# Word Count: 527
# Avg Syllables per Word: 1.5028462998102468
# Personal Pronouns: 12
# Avg Word Length: 4.96584440227704
#
# ----------------------------------------
#
# File: bctech2121.txt
# Subjectivity Score: 0.4167184265010351
# Avg Sentence Length: 90.5
# Percentage of Complex Words: 13.259668508287293
# FOG Index: 41.50386740331492
# Avg Words per Sentence: 90.5
# Complex Word Count: 72
# Word Count: 543
# Avg Syllables per Word: 1.4843462246777164
# Personal Pronouns: 7
# Avg Word Length: 5.298342541436464
#
# ----------------------------------------
#
# File: bctech2131.txt
# Subjectivity Score: 0.4181818181818182
# Avg Sentence Length: 64.0
# Percentage of Complex Words: 25.78125
# FOG Index: 35.9125
# Avg Words per Sentence: 64.0
# Complex Word Count: 33
# Word Count: 128
# Avg Syllables per Word: 1.75
# Personal Pronouns: 0
# Avg Word Length: 6.1328125
#
# ----------------------------------------
#
# File: bctech2074.txt
# Subjectivity Score: 0.24158163265306126
# Avg Sentence Length: 27.5
# Percentage of Complex Words: 21.363636363636363
# FOG Index: 19.545454545454547
# Avg Words per Sentence: 27.5
# Complex Word Count: 47
# Word Count: 220
# Avg Syllables per Word: 1.7454545454545454
# Personal Pronouns: 3
# Avg Word Length: 6.236363636363636
#
# ----------------------------------------
#
# File: bctech2150.txt
# Subjectivity Score: 0.45099206349206344
# Avg Sentence Length: 36.0
# Percentage of Complex Words: 14.957264957264957
# FOG Index: 20.38290598290598
# Avg Words per Sentence: 36.0
# Complex Word Count: 70
# Word Count: 468
# Avg Syllables per Word: 1.4807692307692308
# Personal Pronouns: 7
# Avg Word Length: 4.948717948717949
#
# ----------------------------------------
#
# File: bctech2023.txt
# Subjectivity Score: 0.4297560547560548
# Avg Sentence Length: 42.666666666666664
# Percentage of Complex Words: 20.15625
# FOG Index: 25.129166666666666
# Avg Words per Sentence: 42.666666666666664
# Complex Word Count: 129
# Word Count: 640
# Avg Syllables per Word: 1.63125
# Personal Pronouns: 8
# Avg Word Length: 5.58125
#
# ----------------------------------------
#
# File: bctech2055.txt
# Subjectivity Score: 0.5583874458874459
# Avg Sentence Length: 22.5
# Percentage of Complex Words: 16.363636363636363
# FOG Index: 15.545454545454545
# Avg Words per Sentence: 22.5
# Complex Word Count: 81
# Word Count: 495
# Avg Syllables per Word: 1.4505050505050505
# Personal Pronouns: 18
# Avg Word Length: 4.907070707070707
#
# ----------------------------------------
#
# File: bctech2139.txt
# Subjectivity Score: 0.4702674897119341
# Avg Sentence Length: 33.5
# Percentage of Complex Words: 17.69722814498934
# FOG Index: 20.478891257995738
# Avg Words per Sentence: 33.5
# Complex Word Count: 83
# Word Count: 469
# Avg Syllables per Word: 1.6162046908315566
# Personal Pronouns: 10
# Avg Word Length: 5.20042643923241
#
# ----------------------------------------

# %%
############################### OUTPUT FORMATING USING PANDAS TEXTBLOB TEXTSTAT NLTK ####################################

# %%
import os
import re
import pandas as pd
from textblob import TextBlob
import textstat
import nltk
nltk.download('punkt')

# Define a function to calculate syllables per word using textstat
def syllable_count(word):
    return textstat.syllable_count(word)

# Define a function to check if a word is complex (3 or more syllables)
def is_complex_word(word):
    return syllable_count(word) >= 3

# Define a function to calculate personal pronouns
def count_personal_pronouns(text):
    pronouns = ['I', 'we', 'my', 'ours', 'us', 'he', 'she', 'him', 'her', 'they', 'them', 'you']
    words = text.lower().split()
    return sum(1 for word in words if word in pronouns)

# Define the main function to calculate all factors
def analyze_text_metrics(text):
    # Initialize TextBlob for sentiment and subjectivity
    blob = TextBlob(text)

    # Sentence Tokenization
    sentences = nltk.sent_tokenize(text)
    num_sentences = len(sentences)

    # Word Tokenization
    words = nltk.word_tokenize(text)
    num_words = len(words)

    # Word count and average word length
    total_word_length = sum(len(word) for word in words)
    avg_word_length = total_word_length / num_words if num_words > 0 else 0

    # Subjectivity Score
    subjectivity_score = blob.sentiment.subjectivity

    # Avg Sentence Length (Number of words per sentence)
    avg_sentence_length = num_words / num_sentences if num_sentences > 0 else 0

    # Complex word count
    complex_words = [word for word in words if is_complex_word(word)]
    num_complex_words = len(complex_words)

    # Percentage of complex words
    percentage_complex_words = (num_complex_words / num_words) * 100 if num_words > 0 else 0

    # FOG Index = 0.4 * (average sentence length + percentage of complex words)
    fog_index = 0.4 * (avg_sentence_length + percentage_complex_words)

    # Avg Number of Words per Sentence
    avg_words_per_sentence = num_words / num_sentences if num_sentences > 0 else 0

    # Syllables per word
    syllables = sum(syllable_count(word) for word in words)
    avg_syllables_per_word = syllables / num_words if num_words > 0 else 0

    # Count personal pronouns
    personal_pronouns_count = count_personal_pronouns(text)

    return {
        'subjectivity_score': subjectivity_score,
        'avg_sentence_length': avg_sentence_length,
        'percentage_complex_words': percentage_complex_words,
        'fog_index': fog_index,
        'avg_words_per_sentence': avg_words_per_sentence,
        'complex_word_count': num_complex_words,
        'word_count': num_words,
        'avg_syllables_per_word': avg_syllables_per_word,
        'personal_pronouns': personal_pronouns_count,
        'avg_word_length': avg_word_length
    }

# Folder containing the scraped articles
scraped_articles_folder = 'scraped_articles'

# Create an empty list to store data for each article
data = []

# Loop through each article and calculate metrics
for file_name in os.listdir(scraped_articles_folder):
    if file_name.endswith('.txt'):
        file_path = os.path.join(scraped_articles_folder, file_name)

        # Read the article content
        with open(file_path, 'r', encoding='utf-8') as file:
            text = file.read()

        # Analyze text metrics
        metrics = analyze_text_metrics(text)

        # Append the results to the data list
        data.append({
            'File Name': file_name,
            'Subjectivity Score': metrics['subjectivity_score'],
            'Avg Sentence Length': metrics['avg_sentence_length'],
            'Percentage of Complex Words': metrics['percentage_complex_words'],
            'FOG Index': metrics['fog_index'],
            'Avg Words per Sentence': metrics['avg_words_per_sentence'],
            'Complex Word Count': metrics['complex_word_count'],
            'Word Count': metrics['word_count'],
            'Avg Syllables per Word': metrics['avg_syllables_per_word'],
            'Personal Pronouns': metrics['personal_pronouns'],
            'Avg Word Length': metrics['avg_word_length']
        })

# Convert the data list to a pandas DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to an Excel file
output_excel_file = 'Updated_Output_Data_Structure.xlsx'
df.to_excel(output_excel_file, index=False)

print(f"Analysis results saved to {output_excel_file}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Analysis results saved to Updated_Output_Data_Structure.xlsx

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
df = pd.read_csv('/content/drive/My Drive//content/Updated_Output_Data_Structure.xlsx')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-8d6f89c37632> in <cell line: 4>()
#       2 drive.mount('/content/drive')
#       3 import pandas as pd
# ----> 4 df = pd.read_csv('/content/drive/My Drive//content/Updated_Output_Data_Structure.xlsx')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive//content/Updated_Output_Data_Structure.xlsx'
